# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(cities)
# Out:
# ['samusu', 'kapaa', 'bluff', 'severo-yeniseyskiy', 'totskoye', 'chokurdakh', 'vaini', 'georgetown', 'surt', 'yuancheng', 'port macquarie', 'saint-francois', 'hermanus', 'ushuaia', 'cape town', 'illoqqortoormiut', 'jamestown', 'taolanaro', 'puerto ayora', 'sandwick', 'poum', 'naryan-mar', 'new norfolk', 'alakurtti', 'port blair', 'sribne', 'paamiut', 'amderma', 'port hueneme', 'sedelnikovo', 'utiroa', 'songjianghe', 'mahebourg', 'kahului', 'mataura', 'hihifo', 'airai', 'sena madureira', 'great falls', 'maralal', 'wanlaweyn', 'butaritari', 'hithadhoo', 'rongcheng', 'souillac', 'clyde river', 'lar', 'carnarvon', 'geraldton', 'longyearbyen', 'tsabong', 'lawrence', 'punta arenas', 'daxian', 'rikitea', 'bredasdorp', 'goderich', 'shieli', 'ribeira grande', 'kununurra', 'kropotkin', 'prince rupert', 'port elizabeth', 'novo aripuana', 'khatanga', 'palma', 'albany', 'bambous virieux', 'thompson', 'hilo', 'ye', 'college', 'kaka', 'westport', 'tulun', 'garowe', 'provideniya', 'harlingen', 'fuyu', 'upernavik', 'sitka', 'comodoro rivadavia', 'parabel', 'belle fourche', 'sambava', 'busselton', 'sorvag', 'alto lucero', 'cayenne', 'batemans bay', 'atarra', 'nur', 'kuche', 'atuona', 'chuy', 'yellowknife', 'evensk', 'castro', 'northam', 'victoria', 'salalah', 'qaanaaq', 'fukue', 'novaya lyada', 'san-pedro', 'lethem', 'tari', 'maghama', 'parras', 'dicabisagan', 'fare', 'mingshui', 'orange', 'collie', 'korhogo', 'tete', 'florence', 'tanete', 'alofi', 'shimoda', 'santa ana', 'casper', 'fergus falls', 'asfi', 'saldanha', 'palm coast', 'huarmey', 'roald', 'ostrovnoy', 'minab', 'nyurba', 'sungairaya', 'mocorito', 'barrow', 'pontes e lacerda', 'honiara', 'kodiak', 'nizhneyansk', 'mergui', 'itarema', 'peruibe', 'fortuna', 'asilah', 'ambilobe', 'lebu', 'ponta do sol', 'antofagasta', 'vestmannaeyjar', 'shivrajpur', 'shache', 'nishihara', 'nikolskoye', 'fort nelson', 'lalomanu', 'mugur-aksy', 'te anau', 'neepawa', 'guarapari', 'bengkulu', 'kruisfontein', 'kumluca', 'dukat', 'taoudenni', 'marovoay', 'east london', 'ixtapa', 'kuah', 'sao miguel do araguaia', 'luba', 'north bend', 'leningradskiy', 'tshikapa', 'bur gabo', 'mackay', 'kapit', 'kamenskoye', 'beringovskiy', 'otane', 'syracuse', 'constitucion', 'kuliyapitiya', 'mount gambier', 'shaunavon', 'hobyo', 'peterborough', 'sisimiut', 'sibolga', 'marica', 'hobart', 'esso', 'cabo san lucas', 'umea', 'ilka', 'bitam', 'belushya guba', 'terrace', 'barroualie', 'svetlyy', 'jinchang', 'talnakh', 'tuktoyaktuk', 'coronel oviedo', 'dhidhdhoo', 'esperance', 'henties bay', 'smithers', 'faya', 'agadez', 'tigil', 'pak phanang', 'mys shmidta', 'los llanos de aridane', 'basoko', 'baruun-urt', 'tukrah', 'hambantota', 'podosinovets', 'sansai', 'imbituba', 'san patricio', 'severo-kurilsk', 'faanui', 'padang', 'port alfred', 'burns lake', 'bethel', 'lavrentiya', 'saint-pierre', 'chifeng', 'tianpeng', 'kenai', 'szany', 'pacific grove', 'tumannyy', 'alice springs', 'porto santo', 'luganville', 'road town', 'ginir', 'gangotri', 'tonj', 'la ronge', 'saint-joseph', 'arraial do cabo', 'acapulco', 'awbari', 'broken hill', 'ilinka', 'lokosovo', 'nanortalik', 'yabelo', 'sola', 'christchurch', 'hamilton', 'teeli', 'san andres', 'raahe', 'mocajuba', 'alappuzha', 'belaya gora', 'mumford', 'caidian', 'birin', 'chiredzi', 'buala', 'narsaq', 'kaitangata', 'kavaratti', 'port pirie', 'touros', 'piacabucu', 'turukhansk', 'chkalovskoye', 'dusti', 'nevel', 'oudtshoorn', 'palmer', 'longonjo', 'avarua', 'barentsburg', 'chornobay', 'mpika', 'lagoa', 'tabas', 'kavieng', 'matias olimpio', 'talara', 'hartford', 'bambanglipuro', 'prado', 'adre', 'abu dhabi', 'vaitupu', 'chapais', 'guerrero negro', 'kunya', 'vanimo', 'gannan', 'saint george', 'hofn', 'ryotsu', 'mar del plata', 'pangnirtung', 'ogembo', 'nara', 'freeport', 'dikson', 'gamba', 'kusk', 'ancud', 'omsukchan', 'hay river', 'tiksi', 'perth', 'araguacu', 'husavik', 'oussouye', 'mastic beach', 'kokkola', 'scottsbluff', 'menongue', 'bandarbeyla', 'nuevitas', 'umzimvubu', 'sakakah', 'miyako', 'saint ...

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=dfa734f566cafc5b29c79bc46a224cda

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_weather_description = city_weather['weather'][0]['description']
            # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date,
                              "Current Description": city_weather_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | severo-yeniseyskiy
# Processing Record 5 of Set 1 | totskoye
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | surt
# Processing Record 10 of Set 1 | yuancheng
# Processing Record 11 of Set 1 | port macquarie
# Processing Record 12 of Set 1 | saint-francois
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | sandwick
# Processing Record 21 of Set 1 | poum
# Processing Record 22 of Set 1 | naryan-mar
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | alakurtti
# Processing Record 25 of Set 1 | port blair
# Processing Record 26 of Set 1 | sribne
# Processing Record 27 of Set 1 | paamiut
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | port hueneme
# Processing Record 30 of Set 1 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 1 | songjianghe
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | kahului
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | sena madureira
# Processing Record 39 of Set 1 | great falls
# Processing Record 40 of Set 1 | maralal
# Processing Record 41 of Set 1 | wanlaweyn
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | rongcheng
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | lar
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | geraldton
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | tsabong
# Processing Record 2 of Set 2 | lawrence
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | daxian
# City not found. Skipping...
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | goderich
# Processing Record 8 of Set 2 | shieli
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | kununurra
# Processing Record 11 of Set 2 | kropotkin
# Processing Record 12 of Set 2 | prince rupert
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | novo aripuana
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | palma
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | ye
# City not found. Skipping...
# Processing Record 22 of Set 2 | college
# Processing Record 23 of Set 2 | kaka
# Processing Record 24 of Set 2 | westport
# Processing Record 25 of Set 2 | tulun
# Processing Record 26 of Set 2 | garowe
# Processing Record 27 of Set 2 | provideniya
# Processing Record 28 of Set 2 | harlingen
# Processing Record 29 of Set 2 | fuyu
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | comodoro rivadavia
# Processing Record 33 of Set 2 | parabel
# Processing Record 34 of Set 2 | belle fourche
# Processing Record 35 of Set 2 | sambava
# Processing Record 36 of Set 2 | busselton
# Processing Record 37 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 2 | alto lucero
# Processing Record 39 of Set 2 | cayenne
# Processing Record 40 of Set 2 | batemans bay
# Processing Record 41 of Set 2 | atarra
# Processing Record 42 of Set 2 | nur
# Processing Record 43 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | evensk
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | northam
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | salalah
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | fukue
# Processing Record 4 of Set 3 | novaya lyada
# Processing Record 5 of Set 3 | san-pedro
# Processing Record 6 of Set 3 | lethem
# Processing Record 7 of Set 3 | tari
# Processing Record 8 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 9 of Set 3 | parras
# City not found. Skipping...
# Processing Record 10 of Set 3 | dicabisagan
# Processing Record 11 of Set 3 | fare
# Processing Record 12 of Set 3 | mingshui
# Processing Record 13 of Set 3 | orange
# Processing Record 14 of Set 3 | collie
# Processing Record 15 of Set 3 | korhogo
# Processing Record 16 of Set 3 | tete
# Processing Record 17 of Set 3 | florence
# Processing Record 18 of Set 3 | tanete
# Processing Record 19 of Set 3 | alofi
# Processing Record 20 of Set 3 | shimoda
# Processing Record 21 of Set 3 | santa ana
# Processing Record 22 of Set 3 | casper
# Processing Record 23 of Set 3 | fergus falls
# Processing Record 24 of Set 3 | asfi
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | palm coast
# Processing Record 27 of Set 3 | huarmey
# Processing Record 28 of Set 3 | roald
# Processing Record 29 of Set 3 | ostrovnoy
# Processing Record 30 of Set 3 | minab
# Processing Record 31 of Set 3 | nyurba
# Processing Record 32 of Set 3 | sungairaya
# Processing Record 33 of Set 3 | mocorito
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | pontes e lacerda
# Processing Record 36 of Set 3 | honiara
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 3 | itarema
# Processing Record 41 of Set 3 | peruibe
# Processing Record 42 of Set 3 | fortuna
# Processing Record 43 of Set 3 | asilah
# Processing Record 44 of Set 3 | ambilobe
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | ponta do sol
# Processing Record 47 of Set 3 | antofagasta
# Processing Record 48 of Set 3 | vestmannaeyjar
# Processing Record 49 of Set 3 | shivrajpur
# Processing Record 50 of Set 3 | shache
# Processing Record 1 of Set 4 | nishihara
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | fort nelson
# Processing Record 4 of Set 4 | lalomanu
# City not found. Skipping...
# Processing Record 5 of Set 4 | mugur-aksy
# Processing Record 6 of Set 4 | te anau
# Processing Record 7 of Set 4 | neepawa
# Processing Record 8 of Set 4 | guarapari
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | kumluca
# Processing Record 12 of Set 4 | dukat
# Processing Record 13 of Set 4 | taoudenni
# Processing Record 14 of Set 4 | marovoay
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | ixtapa
# Processing Record 17 of Set 4 | kuah
# Processing Record 18 of Set 4 | sao miguel do araguaia
# Processing Record 19 of Set 4 | luba
# Processing Record 20 of Set 4 | north bend
# Processing Record 21 of Set 4 | leningradskiy
# Processing Record 22 of Set 4 | tshikapa
# Processing Record 23 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 4 | mackay
# Processing Record 25 of Set 4 | kapit
# Processing Record 26 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 4 | beringovskiy
# Processing Record 28 of Set 4 | otane
# Processing Record 29 of Set 4 | syracuse
# Processing Record 30 of Set 4 | constitucion
# Processing Record 31 of Set 4 | kuliyapitiya
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | shaunavon
# Processing Record 34 of Set 4 | hobyo
# Processing Record 35 of Set 4 | peterborough
# Processing Record 36 of Set 4 | sisimiut
# Processing Record 37 of Set 4 | sibolga
# Processing Record 38 of Set 4 | marica
# Processing Record 39 of Set 4 | hobart
# Processing Record 40 of Set 4 | esso
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | umea
# Processing Record 43 of Set 4 | ilka
# City not found. Skipping...
# Processing Record 44 of Set 4 | bitam
# Processing Record 45 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 4 | terrace
# Processing Record 47 of Set 4 | barroualie
# City not found. Skipping...
# Processing Record 48 of Set 4 | svetlyy
# Processing Record 49 of Set 4 | jinchang
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | coronel oviedo
# Processing Record 3 of Set 5 | dhidhdhoo
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | henties bay
# Processing Record 6 of Set 5 | smithers
# Processing Record 7 of Set 5 | faya
# Processing Record 8 of Set 5 | agadez
# Processing Record 9 of Set 5 | tigil
# Processing Record 10 of Set 5 | pak phanang
# Processing Record 11 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 5 | los llanos de aridane
# Processing Record 13 of Set 5 | basoko
# Processing Record 14 of Set 5 | baruun-urt
# Processing Record 15 of Set 5 | tukrah
# Processing Record 16 of Set 5 | hambantota
# Processing Record 17 of Set 5 | podosinovets
# Processing Record 18 of Set 5 | sansai
# City not found. Skipping...
# Processing Record 19 of Set 5 | imbituba
# Processing Record 20 of Set 5 | san patricio
# Processing Record 21 of Set 5 | severo-kurilsk
# Processing Record 22 of Set 5 | faanui
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | port alfred
# Processing Record 25 of Set 5 | burns lake
# Processing Record 26 of Set 5 | bethel
# Processing Record 27 of Set 5 | lavrentiya
# Processing Record 28 of Set 5 | saint-pierre
# Processing Record 29 of Set 5 | chifeng
# Processing Record 30 of Set 5 | tianpeng
# Processing Record 31 of Set 5 | kenai
# Processing Record 32 of Set 5 | szany
# Processing Record 33 of Set 5 | pacific grove
# Processing Record 34 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 5 | alice springs
# Processing Record 36 of Set 5 | porto santo
# Processing Record 37 of Set 5 | luganville
# Processing Record 38 of Set 5 | road town
# Processing Record 39 of Set 5 | ginir
# Processing Record 40 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 41 of Set 5 | tonj
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | saint-joseph
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | acapulco
# Processing Record 46 of Set 5 | awbari
# Processing Record 47 of Set 5 | broken hill
# Processing Record 48 of Set 5 | ilinka
# City not found. Skipping...
# Processing Record 49 of Set 5 | lokosovo
# Processing Record 50 of Set 5 | nanortalik
# Processing Record 1 of Set 6 | yabelo
# Processing Record 2 of Set 6 | sola
# Processing Record 3 of Set 6 | christchurch
# Processing Record 4 of Set 6 | hamilton
# Processing Record 5 of Set 6 | teeli
# Processing Record 6 of Set 6 | san andres
# Processing Record 7 of Set 6 | raahe
# Processing Record 8 of Set 6 | mocajuba
# Processing Record 9 of Set 6 | alappuzha
# Processing Record 10 of Set 6 | belaya gora
# Processing Record 11 of Set 6 | mumford
# Processing Record 12 of Set 6 | caidian
# Processing Record 13 of Set 6 | birin
# Processing Record 14 of Set 6 | chiredzi
# Processing Record 15 of Set 6 | buala
# Processing Record 16 of Set 6 | narsaq
# Processing Record 17 of Set 6 | kaitangata
# Processing Record 18 of Set 6 | kavaratti
# Processing Record 19 of Set 6 | port pirie
# Processing Record 20 of Set 6 | touros
# Processing Record 21 of Set 6 | piacabucu
# Processing Record 22 of Set 6 | turukhansk
# Processing Record 23 of Set 6 | chkalovskoye
# Processing Record 24 of Set 6 | dusti
# Processing Record 25 of Set 6 | nevel
# Processing Record 26 of Set 6 | oudtshoorn
# Processing Record 27 of Set 6 | palmer
# Processing Record 28 of Set 6 | longonjo
# Processing Record 29 of Set 6 | avarua
# Processing Record 30 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 6 | chornobay
# Processing Record 32 of Set 6 | mpika
# Processing Record 33 of Set 6 | lagoa
# Processing Record 34 of Set 6 | tabas
# Processing Record 35 of Set 6 | kavieng
# Processing Record 36 of Set 6 | matias olimpio
# Processing Record 37 of Set 6 | talara
# Processing Record 38 of Set 6 | hartford
# Processing Record 39 of Set 6 | bambanglipuro
# Processing Record 40 of Set 6 | prado
# Processing Record 41 of Set 6 | adre
# Processing Record 42 of Set 6 | abu dhabi
# Processing Record 43 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 6 | chapais
# Processing Record 45 of Set 6 | guerrero negro
# Processing Record 46 of Set 6 | kunya
# Processing Record 47 of Set 6 | vanimo
# Processing Record 48 of Set 6 | gannan
# Processing Record 49 of Set 6 | saint george
# Processing Record 50 of Set 6 | hofn
# Processing Record 1 of Set 7 | ryotsu
# Processing Record 2 of Set 7 | mar del plata
# Processing Record 3 of Set 7 | pangnirtung
# Processing Record 4 of Set 7 | ogembo
# Processing Record 5 of Set 7 | nara
# Processing Record 6 of Set 7 | freeport
# Processing Record 7 of Set 7 | dikson
# Processing Record 8 of Set 7 | gamba
# Processing Record 9 of Set 7 | kusk
# City not found. Skipping...
# Processing Record 10 of Set 7 | ancud
# Processing Record 11 of Set 7 | omsukchan
# Processing Record 12 of Set 7 | hay river
# Processing Record 13 of Set 7 | tiksi
# Processing Record 14 of Set 7 | perth
# Processing Record 15 of Set 7 | araguacu
# Processing Record 16 of Set 7 | husavik
# Processing Record 17 of Set 7 | oussouye
# Processing Record 18 of Set 7 | mastic beach
# Processing Record 19 of Set 7 | kokkola
# Processing Record 20 of Set 7 | scottsbluff
# Processing Record 21 of Set 7 | menongue
# Processing Record 22 of Set 7 | bandarbeyla
# Processing Record 23 of Set 7 | nuevitas
# Processing Record 24 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 7 | sakakah
# Processing Record 26 of Set 7 | miyako
# Processing Record 27 of Set 7 | saint-michel-des-saints
# Processing Record 28 of Set 7 | daru
# Processing Record 29 of Set 7 | qui nhon
# Processing Record 30 of Set 7 | saint-leu
# Processing Record 31 of Set 7 | port hedland
# Processing Record 32 of Set 7 | inuvik
# Processing Record 33 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 7 | pemba
# Processing Record 35 of Set 7 | barcelos
# Processing Record 36 of Set 7 | letlhakane
# Processing Record 37 of Set 7 | asau
# Processing Record 38 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 7 | sinnamary
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | vila velha
# Processing Record 42 of Set 7 | miesbach
# Processing Record 43 of Set 7 | puerto escondido
# Processing Record 44 of Set 7 | anito
# Processing Record 45 of Set 7 | ahipara
# Processing Record 46 of Set 7 | wenling
# Processing Record 47 of Set 7 | yerbogachen
# Processing Record 48 of Set 7 | manuk mangkaw
# Processing Record 49 of Set 7 | flin flon
# Processing Record 50 of Set 7 | anqiu
# Processing Record 1 of Set 8 | tasiilaq
# Processing Record 2 of Set 8 | iqaluit
# Processing Record 3 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 8 | sao filipe
# Processing Record 5 of Set 8 | champerico
# Processing Record 6 of Set 8 | portland
# Processing Record 7 of Set 8 | coihaique
# Processing Record 8 of Set 8 | bandundu
# Processing Record 9 of Set 8 | lompoc
# Processing Record 10 of Set 8 | thinadhoo
# Processing Record 11 of Set 8 | juneau
# Processing Record 12 of Set 8 | kushima
# Processing Record 13 of Set 8 | la tuque
# Processing Record 14 of Set 8 | kutum
# Processing Record 15 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 8 | karachev
# Processing Record 17 of Set 8 | jiangyou
# Processing Record 18 of Set 8 | vardo
# Processing Record 19 of Set 8 | mirpur sakro
# Processing Record 20 of Set 8 | rocha
# Processing Record 21 of Set 8 | dzhida
# Processing Record 22 of Set 8 | plainview
# Processing Record 23 of Set 8 | shelburne
# Processing Record 24 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 8 | adrar
# Processing Record 26 of Set 8 | alugan
# Processing Record 27 of Set 8 | batticaloa
# Processing Record 28 of Set 8 | otjimbingwe
# Processing Record 29 of Set 8 | teguise
# Processing Record 30 of Set 8 | roma
# Processing Record 31 of Set 8 | maraa
# Processing Record 32 of Set 8 | ozernovskiy
# Processing Record 33 of Set 8 | isangel
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | teknaf
# Processing Record 36 of Set 8 | srednekolymsk
# Processing Record 37 of Set 8 | norman wells
# Processing Record 38 of Set 8 | ginda
# Processing Record 39 of Set 8 | broadstairs
# Processing Record 40 of Set 8 | bilibino
# Processing Record 41 of Set 8 | invermere
# Processing Record 42 of Set 8 | ilulissat
# Processing Record 43 of Set 8 | bulalacao
# Processing Record 44 of Set 8 | pevek
# Processing Record 45 of Set 8 | uyuni
# Processing Record 46 of Set 8 | khor
# Processing Record 47 of Set 8 | bermejo
# Processing Record 48 of Set 8 | celestun
# Processing Record 49 of Set 8 | quatre cocos
# Processing Record 50 of Set 8 | bengkalis
# City not found. Skipping...
# Processing Record 1 of Set 9 | woodward
# Processing Record 2 of Set 9 | bud
# Processing Record 3 of Set 9 | tuatapere
# Processing Record 4 of Set 9 | marzuq
# Processing Record 5 of Set 9 | mambatangan
# Processing Record 6 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 9 | richards bay
# Processing Record 8 of Set 9 | key west
# Processing Record 9 of Set 9 | samarai
# Processing Record 10 of Set 9 | salinopolis
# Processing Record 11 of Set 9 | sistranda
# Processing Record 12 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 9 | saskylakh
# Processing Record 14 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 15 of Set 9 | falkoping
# City not found. Skipping...
# Processing Record 16 of Set 9 | cherskiy
# Processing Record 17 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 9 | havoysund
# Processing Record 19 of Set 9 | bathsheba
# Processing Record 20 of Set 9 | luanda
# Processing Record 21 of Set 9 | ejido
# Processing Record 22 of Set 9 | saint-augustin
# Processing Record 23 of Set 9 | semey
# Processing Record 24 of Set 9 | torbay
# Processing Record 25 of Set 9 | nokaneng
# Processing Record 26 of Set 9 | kargat
# Processing Record 27 of Set 9 | sahuaripa
# Processing Record 28 of Set 9 | bubaque
# Processing Record 29 of Set 9 | dera gopipur
# Processing Record 30 of Set 9 | khawhai
# Processing Record 31 of Set 9 | manta
# Processing Record 32 of Set 9 | san quintin
# Processing Record 33 of Set 9 | santa maria del oro
# Processing Record 34 of Set 9 | yar-sale
# Processing Record 35 of Set 9 | quibdo
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | melilla
# Processing Record 38 of Set 9 | maarianhamina
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | turbat
# Processing Record 41 of Set 9 | half moon bay
# Processing Record 42 of Set 9 | tomakomai
# Processing Record 43 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 9 | rolla
# Processing Record 45 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 9 | holetown
# Processing Record 47 of Set 9 | namie
# Processing Record 48 of Set 9 | buluang
# Processing Record 49 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 9 | yubari
# Processing Record 1 of Set 10 | kudahuvadhoo
# Processing Record 2 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 10 | saint-philippe
# Processing Record 4 of Set 10 | rawson
# Processing Record 5 of Set 10 | andenes
# Processing Record 6 of Set 10 | luderitz
# Processing Record 7 of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record 8 of Set 10 | metro
# Processing Record 9 of Set 10 | mogadishu
# Processing Record 10 of Set 10 | birao
# Processing Record 11 of Set 10 | kawambwa
# Processing Record 12 of Set 10 | yatou
# Processing Record 13 of Set 10 | maracacume
# Processing Record 14 of Set 10 | kirakira
# Processing Record 15 of Set 10 | longhua
# Processing Record 16 of Set 10 | fairlie
# Processing Record 17 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 10 | christiana
# Processing Record 19 of Set 10 | teseney
# Processing Record 20 of Set 10 | jaca
# Processing Record 21 of Set 10 | sorland
# Processing Record 22 of Set 10 | bow island
# Processing Record 23 of Set 10 | codrington
# Processing Record 24 of Set 10 | sinjar
# Processing Record 25 of Set 10 | grindavik
# Processing Record 26 of Set 10 | sao bento
# Processing Record 27 of Set 10 | khuzhir
# Processing Record 28 of Set 10 | shenjiamen
# Processing Record 29 of Set 10 | shingu
# Processing Record 30 of Set 10 | aykhal
# Processing Record 31 of Set 10 | ibra
# Processing Record 32 of Set 10 | biak
# Processing Record 33 of Set 10 | rabo de peixe
# Processing Record 34 of Set 10 | almaznyy
# Processing Record 35 of Set 10 | chippewa falls
# Processing Record 36 of Set 10 | xam nua
# Processing Record 37 of Set 10 | kepala batas
# Processing Record 38 of Set 10 | sao felix do xingu
# Processing Record 39 of Set 10 | aksha
# Processing Record 40 of Set 10 | palora
# Processing Record 41 of Set 10 | lumphat
# Processing Record 42 of Set 10 | ponta delgada
# Processing Record 43 of Set 10 | naze
# Processing Record 44 of Set 10 | kupang
# Processing Record 45 of Set 10 | tiznit
# Processing Record 46 of Set 10 | yulara
# Processing Record 47 of Set 10 | cidreira
# Processing Record 48 of Set 10 | santa lucia
# Processing Record 49 of Set 10 | doka
# Processing Record 50 of Set 10 | san buenaventura
# Processing Record 1 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 11 | kunming
# Processing Record 3 of Set 11 | joensuu
# Processing Record 4 of Set 11 | miles city
# Processing Record 5 of Set 11 | nagornyy
# Processing Record 6 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 11 | alekseyevka
# Processing Record 8 of Set 11 | ferrol
# Processing Record 9 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 11 | mandurah
# Processing Record 11 of Set 11 | urubamba
# Processing Record 12 of Set 11 | rozivka
# Processing Record 13 of Set 11 | sault sainte marie
# Processing Record 14 of Set 11 | grand-santi
# Processing Record 15 of Set 11 | byron bay
# Processing Record 16 of Set 11 | patti
# Processing Record 17 of Set 11 | chatra
# Processing Record 18 of Set 11 | amapa
# Processing Record 19 of Set 11 | ziniare
# Processing Record 20 of Set 11 | tokur
# Processing Record 21 of Set 11 | nelson bay
# Processing Record 22 of Set 11 | larsnes
# Processing Record 23 of Set 11 | kloulklubed
# Processing Record 24 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 11 | rundu
# Processing Record 26 of Set 11 | eyl
# Processing Record 27 of Set 11 | lata
# Processing Record 28 of Set 11 | najran
# Processing Record 29 of Set 11 | panama city
# Processing Record 30 of Set 11 | koroni
# Processing Record 31 of Set 11 | mama
# Processing Record 32 of Set 11 | wattegama
# Processing Record 33 of Set 11 | dalvik
# Processing Record 34 of Set 11 | nome
# Processing Record 35 of Set 11 | waipawa
# Processing Record 36 of Set 11 | skibbereen
# Processing Record 37 of Set 11 | uspenka
# Processing Record 38 of Set 11 | zhigansk
# Processing Record 39 of Set 11 | mabaruma
# Processing Record 40 of Set 11 | pompeu
# Processing Record 41 of Set 11 | yefimovskiy
# City not found. Skipping...
# Processing Record 42 of Set 11 | avera
# Processing Record 43 of Set 11 | abeche
# Processing Record 44 of Set 11 | haines junction
# Processing Record 45 of Set 11 | labytnangi
# Processing Record 46 of Set 11 | zhangye
# Processing Record 47 of Set 11 | teruel
# Processing Record 48 of Set 11 | impfondo
# Processing Record 49 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 11 | marawi
# Processing Record 1 of Set 12 | harper
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | hirara
# Processing Record 4 of Set 12 | turochak
# Processing Record 5 of Set 12 | anadyr
# Processing Record 6 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 12 | dongning
# Processing Record 8 of Set 12 | sirjan
# Processing Record 9 of Set 12 | matagami
# Processing Record 10 of Set 12 | houston
# Processing Record 11 of Set 12 | nago
# Processing Record 12 of Set 12 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 13 of Set 12 | axim
# Processing Record 14 of Set 12 | malanje
# Processing Record 15 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 16 of Set 12 | camocim
# Processing Record 17 of Set 12 | coquimbo
# Processing Record 18 of Set 12 | santa marta
# Processing Record 19 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 12 | livingstone
# Processing Record 21 of Set 12 | kokopo
# Processing Record 22 of Set 12 | klaksvik
# Processing Record 23 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 24 of Set 12 | kieta
# Processing Record 25 of Set 12 | muzhi
# Processing Record 26 of Set 12 | lengshuijiang
# Processing Record 27 of Set 12 | taber
# Processing Record 28 of Set 12 | changping
# Processing Record 29 of Set 12 | urucara
# Processing Record 30 of Set 12 | vilia
# Processing Record 31 of Set 12 | santa maria da vitoria
# Processing Record 32 of Set 12 | baijiantan
# Processing Record 33 of Set 12 | tura
# Processing Record 34 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 12 | kangasala
# Processing Record 36 of Set 12 | mareeba
# Processing Record 37 of Set 12 | quchan
# Processing Record 38 of Set 12 | rancho palos verdes
# Processing Record 39 of Set 12 | oranjemund
# Processing Record 40 of Set 12 | san cristobal
# Processing Record 41 of Set 12 | yarada
# Processing Record 42 of Set 12 | alyangula
# Processing Record 43 of Set 12 | juncos
# Processing Record 44 of Set 12 | lagos
# Processing Record 45 of Set 12 | ylivieska
# Processing Record 46 of Set 12 | chegdomyn
# Processing Record 47 of Set 12 | lingao
# Processing Record 48 of Set 12 | lorengau
# Processing Record 49 of Set 12 | kamenka
# Processing Record 50 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 13 | hervey bay
# Processing Record 2 of Set 13 | bagdarin
# Processing Record 3 of Set 13 | west fargo
# Processing Record 4 of Set 13 | progreso
# Processing Record 5 of Set 13 | weligama
# Processing Record 6 of Set 13 | tautira
# Processing Record 7 of Set 13 | cockburn town
# Processing Record 8 of Set 13 | heiligenhafen
# Processing Record 9 of Set 13 | los andes
# Processing Record 10 of Set 13 | blenheim
# Processing Record 11 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 12 of Set 13 | deputatskiy
# Processing Record 13 of Set 13 | mercedes
# Processing Record 14 of Set 13 | lalsk
# Processing Record 15 of Set 13 | brae
# Processing Record 16 of Set 13 | kitimat
# Processing Record 17 of Set 13 | whitstable
# Processing Record 18 of Set 13 | olafsvik
# Processing Record 19 of Set 13 | port lincoln
# Processing Record 20 of Set 13 | starosubkhangulovo
# Processing Record 21 of Set 13 | saint-louis
# Processing Record 22 of Set 13 | igrim
# Processing Record 23 of Set 13 | okhotsk
# Processing Record 24 of Set 13 | makakilo city
# Processing Record 25 of Set 13 | bilma
# Processing Record 26 of Set 13 | kyaukse
# Processing Record 27 of Set 13 | el alto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 566

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Kapaa  22.0752 -159.3190     73.38        83          44
# 1               Bluff -46.6000  168.3333     48.20        76          40
# 2  Severo-Yeniseyskiy  60.3725   93.0408    -20.54        95          65
# 3            Totskoye  52.5248   52.7623     10.85        96          31
# 4          Chokurdakh  70.6333  147.9167     -6.59        99          87
# 5               Vaini -21.2000 -175.2000     78.96        94          40
# 6          Georgetown   5.4112  100.3354     82.33        85          20
# 7                Surt  31.2089   16.5887     65.37        60         100
# 8           Yuancheng  36.6520  107.7896     26.01        43           1
# 9      Port Macquarie -31.4333  152.9167     57.88        83          30
#
#    Wind Speed Country                 Date Current Description
# 0        1.99      US  2022-12-20 14:58:47    scattered clouds
# 1       11.48      NZ  2022-12-20 14:58:48    scattered clouds
# 2        2.91      RU  2022-12-20 14:58:48       broken clouds
# 3        3.40      RU  2022-12-20 14:58:48    scattered clouds
# 4        2.86      RU  2022-12-20 14:58:49     overcast clouds
# 5        4.61      TO  2022-12-20 14:58:49    scattered clouds
# 6        5.75      MY  2022-12-20 14:56:55          few clouds
# 7       14.45      LY  2022-12-20 14:58:50     overcast clouds
# 8       16.55      CN  2022-12-20 14:58:50           clear sky
# 9        7.11      AU  2022-12-20 14:58:50    scattered clouds

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Kapaa  22.0752 -159.3190     73.38        83          44
# 1               Bluff -46.6000  168.3333     48.20        76          40
# 2  Severo-Yeniseyskiy  60.3725   93.0408    -20.54        95          65
# 3            Totskoye  52.5248   52.7623     10.85        96          31
# 4          Chokurdakh  70.6333  147.9167     -6.59        99          87
# 5               Vaini -21.2000 -175.2000     78.96        94          40
# 6          Georgetown   5.4112  100.3354     82.33        85          20
# 7                Surt  31.2089   16.5887     65.37        60         100
# 8           Yuancheng  36.6520  107.7896     26.01        43           1
# 9      Port Macquarie -31.4333  152.9167     57.88        83          30
#
#    Wind Speed Country                 Date Current Description
# 0        1.99      US  2022-12-20 14:58:47    scattered clouds
# 1       11.48      NZ  2022-12-20 14:58:48    scattered clouds
# 2        2.91      RU  2022-12-20 14:58:48       broken clouds
# 3        3.40      RU  2022-12-20 14:58:48    scattered clouds
# 4        2.86      RU  2022-12-20 14:58:49     overcast clouds
# 5        4.61      TO  2022-12-20 14:58:49    scattered clouds
# 6        5.75      MY  2022-12-20 14:56:55          few clouds
# 7       14.45      LY  2022-12-20 14:58:50     overcast clouds
# 8       16.55      CN  2022-12-20 14:58:50           clear sky
# 9        7.11      AU  2022-12-20 14:58:50    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
city_data_df.count()
# Out:
# City                   566
# Lat                    566
# Lng                    566
# Max Temp               566
# Humidity               566
# Cloudiness             566
# Wind Speed             566
# Country                566
# Date                   566
# Current Description    566
# dtype: int64

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]

# Recreate the DataFrame by using the new column order
city_data_df.count()

# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Kapaa      US  22.0752 -159.3190     73.38        83
# 1               Bluff      NZ -46.6000  168.3333     48.20        76
# 2  Severo-Yeniseyskiy      RU  60.3725   93.0408    -20.54        95
# 3            Totskoye      RU  52.5248   52.7623     10.85        96
# 4          Chokurdakh      RU  70.6333  147.9167     -6.59        99
# 5               Vaini      TO -21.2000 -175.2000     78.96        94
# 6          Georgetown      MY   5.4112  100.3354     82.33        85
# 7                Surt      LY  31.2089   16.5887     65.37        60
# 8           Yuancheng      CN  36.6520  107.7896     26.01        43
# 9      Port Macquarie      AU -31.4333  152.9167     57.88        83
#
#    Cloudiness  Wind Speed Current Description
# 0          44        1.99    scattered clouds
# 1          40       11.48    scattered clouds
# 2          65        2.91       broken clouds
# 3          31        3.40    scattered clouds
# 4          87        2.86     overcast clouds
# 5          40        4.61    scattered clouds
# 6          20        5.75          few clouds
# 7         100       14.45     overcast clouds
# 8           1       16.55           clear sky
# 9          30        7.11    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# %%
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
